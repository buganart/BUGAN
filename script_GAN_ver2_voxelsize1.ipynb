# %% [markdown]
# <a href="https://colab.research.google.com/github/buganart/BUGAN/blob/master/script_GAN_ver2_voxelsize1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#mount google drive
from google.colab import output
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
#right click shared folder IRCMS_GAN_collaborative_database and "Add shortcut to Drive" to My drive
# %cd drive/My Drive/IRCMS_GAN_collaborative_database/Research/Peter/Tree_3D_models_obj/generated_files/
# !ls
# Out:
# /content/drive/.shortcut-targets-by-id/1ylB2p6N0qQ-G4OsBuwcZ9C0tsqVu9ww4/IRCMS_GAN_collaborative_database/Research/Peter/Tree_3D_models_obj/generated_files
# maple_1_voxel_size03.ply  old_1_voxel_size1.ply   old_3_voxel_size1.ply
# maple_2_voxel_size03.ply  old_2_voxel_size1.ply   wandb
# maple_3_voxel_size03.ply  old_3_voxel_size03.ply

# %%
# !pip install open3d
# !pip install wandb -q
output.clear()

# %% [markdown]
# #add libraries, and login to wandb

# %%
import open3d as o3d
import numpy as np

import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torchsummary import summary
from torch.utils.data import DataLoader, TensorDataset
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
device

# Ignore excessive warnings
import logging
logging.propagate = False 
logging.getLogger().setLevel(logging.ERROR)

# WandB – Import the wandb library
import wandb

# %%
# !wandb login
output.clear()

# %%
wandb.init(project="tree-gan")
wandb.run.name = str(wandb.run.entity) +" modelv3 AUG g0.3d0.1 "+ str(wandb.run.id) # number N after g and d means lr are 0.0001 * N
wandb.watch_called = False
# Out:
#                 Logging results to <a href="https://wandb.com" target="_blank">Weights & Biases</a> <a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">(Documentation)</a>.<br/>
#                 Project page: <a href="https://app.wandb.ai/bugan/tree-gan" target="_blank">https://app.wandb.ai/bugan/tree-gan</a><br/>
#                 Run page: <a href="https://app.wandb.ai/bugan/tree-gan/runs/27wc9v9t" target="_blank">https://app.wandb.ai/bugan/tree-gan/runs/27wc9v9t</a><br/>

# %%
#keep track of hyperparams
config = wandb.config
config.batch_size = 3
config.test_batch_size = 1
config.epochs = 10000
config.g_lr = 0.00003
config.d_lr = 0.00001            
config.seed = 1234
config.log_interval = 200

# %% [markdown]
# #dataset

# %%
def voxel2arrayCentered(voxel, tree_size_scale = 1):
    array_size = np.array([70, 70, 70])
    vox_array = np.zeros(array_size, dtype=int)  
    tree_size = np.array(voxel.get_axis_aligned_bounding_box().get_extent())
    tree_size = np.ceil(tree_size / tree_size_scale)    #voxel_size = tree_size_scale
    tree_center = (np.ceil(tree_size / 2)).astype(int)

    vox_list = voxel.get_voxels()
    for vox in vox_list:
        coord = vox.grid_index
        #center the tree
        coord = coord - tree_center + (array_size/2)
        coord = tuple(coord.astype(int))

        vox_array[coord] = 1.

    return vox_array.astype(bool)

# %%
#process all files in the generated file folder to generate dataset 
import os

dataset = []
for file_name in os.listdir():
    if file_name.endswith("voxel_size1.ply"):
        #note that the voxel_size of vox is 0.3, so we scale it back to one for indexing
        print(file_name)
        dataset.append(voxel2arrayCentered(o3d.io.read_voxel_grid(file_name), 1))
# Out:
# old_1_voxel_size1.ply
# old_2_voxel_size1.ply
# old_3_voxel_size1.ply

# %%
dataset = torch.tensor(dataset)
print(torch.unsqueeze(dataset, -1).shape)
tensor_dataset = TensorDataset(torch.unsqueeze(dataset, 1))
dataloader = DataLoader(tensor_dataset, batch_size=config.batch_size)
# Out:
# torch.Size([3, 70, 70, 70, 1])

# %% [markdown]
# #model description

# %%
#input: 128-d noise vector
#output: (250,250,250) array with values in [0,1]

class Generator(nn.Module):
    def __init__(self):
        super(Generator, self).__init__()

        self.fc_channel = 8 #16
        self.fc_size = 5

        num_unit1 = self.fc_channel   
        num_unit2 = 16   #32
        num_unit3 = 32   #64
        num_unit4 = 64   #128
        num_unit5 = 128   #256
        num_unit6 = 256   #512
        self.gen_fc = nn.Linear(128, num_unit1 * self.fc_size * self.fc_size * self.fc_size)
        self.gen = nn.Sequential(

            nn.ConvTranspose3d(num_unit1, num_unit2, 3, 1),
            nn.BatchNorm3d(num_unit2),
            nn.ReLU(True),
            nn.ConvTranspose3d(num_unit2, num_unit3, 3, 1),
            nn.BatchNorm3d(num_unit3),
            nn.ReLU(True),
            nn.ConvTranspose3d(num_unit3, num_unit3, 3, 1),
            nn.BatchNorm3d(num_unit3),
            nn.ReLU(True),
            nn.ConvTranspose3d(num_unit3, num_unit4, 3, 1),
            nn.BatchNorm3d(num_unit4),
            nn.ReLU(True),
            

            nn.Upsample(scale_factor=2, mode='trilinear'),

            nn.ConvTranspose3d(num_unit4, num_unit5, 3, 1),
            nn.BatchNorm3d(num_unit5),
            nn.ReLU(True),
            nn.ConvTranspose3d(num_unit5, num_unit6, 3, 1),
            nn.BatchNorm3d(num_unit6),
            nn.ReLU(True),
            nn.ConvTranspose3d(num_unit6, num_unit5, 3, 1),
            nn.BatchNorm3d(num_unit5),
            nn.ReLU(True),

            nn.Upsample(scale_factor=2, mode='trilinear'),


            nn.ConvTranspose3d(num_unit5, num_unit3, 3, 1),
            nn.BatchNorm3d(num_unit3),
            nn.ReLU(True),
            nn.ConvTranspose3d(num_unit3, num_unit1, 3, 1),
            nn.BatchNorm3d(num_unit1),
            nn.ReLU(True),
            nn.ConvTranspose3d(num_unit1, 1, 3, 1),
            nn.Sigmoid()
        )

    def forward(self, x):

        x = self.gen_fc(x)
        x = x.view(x.shape[0], self.fc_channel, self.fc_size, self.fc_size, self.fc_size)
        x = self.gen(x)
        return x


class Discriminator(nn.Module):
    def __init__(self):
        super(Discriminator, self).__init__()

        num_unit1 = 8   #16
        num_unit2 = 16   #32
        num_unit3 = 32   #64
        num_unit4 = 64  #128
        num_unit5 = 128   #256
        num_unit6 = 256   #512
        
        self.dis = nn.Sequential(
            nn.Conv3d(1, num_unit1, 3, 1, padding = 1),
            nn.BatchNorm3d(num_unit1),
            nn.ReLU(True),
            nn.Conv3d(num_unit1, num_unit2, 3, 1, padding = 1),
            nn.BatchNorm3d(num_unit2),
            nn.ReLU(True),
            nn.Conv3d(num_unit2, num_unit3, 3, 1, padding = 1),
            nn.BatchNorm3d(num_unit3),
            nn.ReLU(True),

            nn.MaxPool3d((2, 2, 2)),

            nn.Conv3d(num_unit3, num_unit3, 3, 1, padding = 1),
            nn.BatchNorm3d(num_unit3),
            nn.ReLU(True),
            nn.Conv3d(num_unit3, num_unit4, 3, 1, padding = 1),
            nn.BatchNorm3d(num_unit4),
            nn.ReLU(True),

            nn.MaxPool3d((2, 2, 2)),

            nn.Conv3d(num_unit4, num_unit5, 3, 1, padding = 1),
            nn.BatchNorm3d(num_unit5),
            nn.ReLU(True),
            nn.Conv3d(num_unit5, num_unit5, 3, 1, padding = 1),
            nn.BatchNorm3d(num_unit5),
            nn.ReLU(True),
            nn.Conv3d(num_unit5, num_unit4, 3, 1, padding = 1),
            nn.BatchNorm3d(num_unit4),
            nn.ReLU(True),

            nn.MaxPool3d((2, 2, 2)),

            nn.Conv3d(num_unit4, num_unit3, 3, 1, padding = 1),
            nn.BatchNorm3d(num_unit3),
            nn.ReLU(True),            
            nn.Conv3d(num_unit3, num_unit2, 3, 1, padding = 1),
            nn.BatchNorm3d(num_unit2),
            nn.ReLU(True),

            nn.MaxPool3d((2, 2, 2)),


            nn.Conv3d(num_unit2, num_unit1, 3, 1, padding = 1),
            nn.BatchNorm3d(num_unit1),
            nn.ReLU(True),
            nn.Conv3d(num_unit1, num_unit1, 3, 1, padding = 1),
            nn.BatchNorm3d(num_unit1),
            nn.ReLU(True),
        )

        self.dis_fc = nn.Sequential(
            nn.Linear(num_unit1 * 4 * 4 * 4, 128),
            nn.LeakyReLU(0.1, True),
            nn.Linear(128, 1),
            nn.Sigmoid()
        )

    def forward(self, x):

        x = self.dis(x)
        x = x.view(x.shape[0], -1)
        x = self.dis_fc(x)
        return x

# %%
# G = Generator().to(device)
# summary(G, (128,))

# %%
# D = Discriminator().to(device)
# summary(D, (1, 70, 70, 70))

# %% [markdown]
# #functions for pytorch network

# %%
def array2voxel(array):
    coord_list = []
    if len(array.shape) == 5:
        array = array[0][0]
    x,y,z = array.shape
    for i in range(x):
        for j in range(y):
            for k in range(z):
                if array[i,j,k] > 0.5:
                    coord_list.append([i,j,k])
    print(len(coord_list))
    if len(coord_list) == 0:
        return np.array([[0,0,0]])  #return at least one point to prevent wandb 3dobject error
    return np.array(coord_list)

def train_model(generator, discriminator, dataloader):   
    generator.to(device)
    discriminator.to(device)
    
    #loss function
    criterion = nn.BCELoss(reduction='sum')
    #optimizer
    # dis_optimizer = optim.SGD(discriminator.parameters(), lr=config.d_lr)
    # gen_optimizer = optim.SGD(generator.parameters(), lr=config.g_lr)   
    dis_optimizer = optim.Adam(discriminator.parameters(), lr=config.d_lr)
    gen_optimizer = optim.Adam(generator.parameters(), lr=config.g_lr)

    #log models
    wandb.watch(generator, log="all")
    wandb.watch(discriminator, log="all")

    d_losses = []
    g_losses = []
    for epoch in range(config.epochs):
        generator.train()
        discriminator.train()

        d_ep_loss = 0.
        g_ep_loss = 0.
        for dataset_batch in dataloader:

            dataset_batch = dataset_batch[0]
            #add data augmentation (rotate 90/180/270)
            #this modify the whole batch at the same time
            rand_num = torch.randn(2)
            if rand_num[0] > 0.5:
                dataset_batch = dataset_batch.permute(0, 1, 3,2,4)
            if rand_num[1] > 0.5: 
                dataset_batch = dataset_batch.flip([4])
                
            dataset_batch = dataset_batch.float().to(device)
            dloss, gloss = compute_loss(generator, discriminator, dataset_batch)


            #optimize generator
            gen_optimizer.zero_grad()
            gloss.backward()
            gen_optimizer.step()

            #optimize discriminator
            dis_optimizer.zero_grad()
            dloss.backward()
            dis_optimizer.step()
          

            #record loss
            d_ep_loss += dloss.detach()  
            g_ep_loss += gloss.detach()

        #after each epoch, record total loss and sample generated obj
        d_losses.append(d_ep_loss)
        g_losses.append(g_ep_loss)
        print("discriminator, epoch"+str(epoch)+" : "+str(d_ep_loss))
        print("generator, epoch"+str(epoch)+" : "+str(g_ep_loss))

        #save model if necessary
        if epoch % config.log_interval == 0:
            sample_tree = array2voxel(generate_tree(generator))

            wandb.log({
            "discriminator loss": d_ep_loss,
            "generator loss": g_ep_loss,
            "sample_tree": wandb.Object3D(sample_tree)})
            torch.save(generator.state_dict(), os.path.join(wandb.run.dir, 'generator.pth'))
            torch.save(discriminator.state_dict(), os.path.join(wandb.run.dir, 'discriminator.pth'))
        else:
            wandb.log({
            "discriminator loss": d_ep_loss,
            "generator loss": g_ep_loss})
    
    #training end, save model again
    sample_tree = array2voxel(generate_tree(generator))

    wandb.log({
    "discriminator loss": d_ep_loss,
    "generator loss": g_ep_loss,
    "sample_tree": wandb.Object3D(sample_tree)})
    torch.save(generator.state_dict(), os.path.join(wandb.run.dir, 'generator.pth'))
    torch.save(discriminator.state_dict(), os.path.join(wandb.run.dir, 'discriminator.pth'))
    
    print(d_losses)
    print(g_losses)

# this function calculate loss of the model, 
def compute_loss(generator, discriminator, dataset_batch):
    
    #loss function
    criterion = nn.BCELoss(reduction='sum')   

    batch_size = dataset_batch.shape[0]
        
    #labels
    real_label = torch.unsqueeze(torch.ones(batch_size),1).float().to(device)
    fake_label = torch.unsqueeze(torch.zeros(batch_size),1).float().to(device)

    ############
    #   discriminator
    ############
    #generate fake trees
    z = torch.randn(batch_size, 128).float().to(device) #128-d noise vector
    tree_fake = generator(z)

    #real data (data from dataloader)
    dout_real = discriminator(dataset_batch)
    dloss_real = criterion(dout_real, real_label)
    score_real = dout_real
    #fake data (data from generator)            
    dout_fake = discriminator(tree_fake.clone().detach())   #detach so no double update on the same batch of tree_fake
    dloss_fake = criterion(dout_fake, fake_label)
    score_fake = dout_fake

    #loss function (discriminator classify real data vs generated data)
    dloss = dloss_real + dloss_fake

    ############
    #   generator
    ############

    #tree_fake is already computed above
    dout_fake = discriminator(tree_fake)
    #generator should generate trees that discriminator think they are real
    gloss = criterion(dout_fake, real_label)    

    return dloss, gloss


def save_model(generator, discriminator, g_path = os.path.join(wandb.run.dir, 'generator.pth') , d_path = os.path.join(wandb.run.dir, 'discriminator.pth')):
    torch.save(generator.state_dict(), g_path)
    torch.save(discriminator.state_dict(), d_path)

def load_model(g_path = os.path.join(wandb.run.dir, 'generator.pth'), d_path = os.path.join(wandb.run.dir, 'discriminator.pth')):
    generator = Generator()
    generator.load_state_dict(torch.load(g_path))
    generator.eval()

    discriminator = Discriminator()
    discriminator.load_state_dict(torch.load(d_path))
    discriminator.eval()
    return generator, discriminator

def generate_tree(generator, num_trees = 1):
    
    #generate noise vector
    z = torch.randn(num_trees, 128).to(device)
    generator.to(device).eval()
    tree_fake = generator(z)
    return tree_fake.detach().cpu().numpy()

# %% [markdown]
# #train

# %%
#set seed
torch.manual_seed(config.seed)
torch.autograd.set_detect_anomaly(True)

G = Generator()
D = Discriminator()
train_model(G, D, dataloader)        #if dataloader has only 1 tree, the training time is 72s per epoch.
# Out:
# /usr/local/lib/python3.6/dist-packages/torch/nn/functional.py:2973: UserWarning: Default upsampling behavior when mode=trilinear is changed to align_corners=False since 0.4.0. Please specify align_corners=True if the old behavior is desired. See the documentation of nn.Upsample for details.
#   "See the documentation of nn.Upsample for details.".format(mode))
# discriminator, epoch0 : tensor(4.0447, device='cuda:0')
# generator, epoch0 : tensor(2.0629, device='cuda:0')
# 0
# /usr/local/lib/python3.6/dist-packages/wandb/data_types.py:464: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   elif 'type' in data_or_path:
# discriminator, epoch1 : tensor(4.2578, device='cuda:0')
# generator, epoch1 : tensor(2.0563, device='cuda:0')
# discriminator, epoch2 : tensor(3.9700, device='cuda:0')
# generator, epoch2 : tensor(2.1910, device='cuda:0')
# discriminator, epoch3 : tensor(4.0118, device='cuda:0')
# generator, epoch3 : tensor(2.0009, device='cuda:0')
# discriminator, epoch4 : tensor(4.1448, device='cuda:0')
# generator, epoch4 : tensor(2.0167, device='cuda:0')
# discriminator, epoch5 : tensor(3.9922, device='cuda:0')
# generator, epoch5 : tensor(2.1213, device='cuda:0')
# discriminator, epoch6 : tensor(3.7440, device='cuda:0')
# generator, epoch6 : tensor(2.1312, device='cuda:0')
# discriminator, epoch7 : tensor(3.6700, device='cuda:0')
# generator, epoch7 : tensor(2.1844, device='cuda:0')
# discriminator, epoch8 : tensor(4.0123, device='cuda:0')
# generator, epoch8 : tensor(2.2927, device='cuda:0')
# discriminator, epoch9 : tensor(3.5994, device='cuda:0')
# generator, epoch9 : tensor(2.1976, device='cuda:0')
# discriminator, epoch10 : tensor(3.6291, device='cuda:0')
# generator, epoch10 : tensor(2.1478, device='cuda:0')
# discriminator, epoch11 : tensor(3.5071, device='cuda:0')
# generator, epoch11 : tensor(2.2392, device='cuda:0')
# discriminator, epoch12 : tensor(3.4052, device='cuda:0')
# generator, epoch12 : tensor(2.3617, device='cuda:0')
# discriminator, epoch13 : tensor(3.4965, device='cuda:0')
# generator, epoch13 : tensor(2.2273, device='cuda:0')
# discriminator, epoch14 : tensor(3.8591, device='cuda:0')
# generator, epoch14 : tensor(2.3313, device='cuda:0')
# discriminator, epoch15 : tensor(3.2356, device='cuda:0')
# generator, epoch15 : tensor(2.4699, device='cuda:0')
# discriminator, epoch16 : tensor(3.2448, device='cuda:0')
# generator, epoch16 : tensor(2.4156, device='cuda:0')
# discriminator, epoch17 : tensor(3.2452, device='cuda:0')
# generator, epoch17 : tensor(2.3770, device='cuda:0')
# discriminator, epoch18 : tensor(3.5893, device='cuda:0')
# generator, epoch18 : tensor(2.5440, device='cuda:0')
# discriminator, epoch19 : tensor(3.5930, device='cuda:0')
# generator, epoch19 : tensor(2.4932, device='cuda:0')
# discriminator, epoch20 : tensor(3.1781, device='cuda:0')
# generator, epoch20 : tensor(2.5125, device='cuda:0')
# discriminator, epoch21 : tensor(3.2050, device='cuda:0')
# generator, epoch21 : tensor(2.4534, device='cuda:0')
# discriminator, epoch22 : tensor(2.9684, device='cuda:0')
# generator, epoch22 : tensor(2.6002, device='cuda:0')
# discriminator, epoch23 : tensor(2.9618, device='cuda:0')
# generator, epoch23 : tensor(2.5847, device='cuda:0')
# discriminator, epoch24 : tensor(3.4446, device='cuda:0')
# generator, epoch24 : tensor(2.5584, device='cuda:0')
# discriminator, epoch25 : tensor(2.8295, device='cuda:0')
# generator, epoch25 : tensor(2.7257, device='cuda:0')
# discriminator, epoch26 : tensor(2.7792, device='cuda:0')
# generator, epoch26 : tensor(2.7760, device='cuda:0')
# discriminator, epoch27 : tensor(2.7752, device='cuda:0')
# generator, epoch27 : tensor(2.7556, device='cuda:0')
# discriminator, epoch28 : tensor(3.2909, device='cuda:0')
# generator, epoch28 : tensor(2.6774, device='cuda:0')
# discriminator, epoch29 : tensor(2.7239, device='cuda:0')
# generator, epoch29 : tensor(2.7805, device='cuda:0')
# discriminator, epoch30 : tensor(2.8700, device='cuda:0')
# generator, epoch30 : tensor(2.8469, device='cuda:0')
# discriminator, epoch31 : tensor(2.8603, device='cuda:0')
# generator, epoch31 : tensor(2.8298, device='cuda:0')
# discriminator, epoch32 : tensor(2.6783, device='cuda:0')
# generator, epoch32 : tensor(2.7809, device='cuda:0')
# discriminator, epoch33 : tensor(2.7603, device='cuda:0')
# generator, epoch33 : tensor(2.9297, device='cuda:0')
# discriminator, epoch34 : tensor(2.6083, device='cuda:0')
# generator, epoch34 : tensor(2.8348, device='cuda:0')
# discriminator, epoch35 : tensor(3.0912, device='cuda:0')
# generator, epoch35 : tensor(2.9612, device='cuda:0')
# discriminator, epoch36 : tensor(2.6991, device='cuda:0')
# generator, epoch36 : tensor(2.9361, device='cuda:0')
# discriminator, epoch37 : tensor(3.0435, device='cuda:0')
# generator, epoch37 : tensor(2.9820, device='cuda:0')
# discriminator, epoch38 : tensor(2.5563, device='cuda:0')
# generator, epoch38 : tensor(2.8459, device='cuda:0')
# discriminator, epoch39 : tensor(3.0180, device='cuda:0')
# generator, epoch39 : tensor(2.9180, device='cuda:0')
# discriminator, epoch40 : tensor(2.4143, device='cuda:0')
# generator, epoch40 : tensor(3.0318, device='cuda:0')
# discriminator, epoch41 : tensor(2.4292, device='cuda:0')
# generator, epoch41 : tensor(2.9816, device='cuda:0')
# discriminator, epoch42 : tensor(3.0452, device='cuda:0')
# generator, epoch42 : tensor(2.8113, device='cuda:0')
# discriminator, epoch43 : tensor(2.8763, device='cuda:0')
# generator, epoch43 : tensor(2.9481, device='cuda:0')
# discriminator, epoch44 : tensor(2.6433, device='cuda:0')
# generator, epoch44 : tensor(2.9068, device='cuda:0')
# discriminator, epoch45 : tensor(2.8317, device='cuda:0')
# generator, epoch45 : tensor(3.0455, device='cuda:0')
# discriminator, epoch46 : tensor(2.8686, device='cuda:0')
# generator, epoch46 : tensor(2.8382, device='cuda:0')
# discriminator, epoch47 : tensor(2.3830, device='cuda:0')
# generator, epoch47 : tensor(2.9784, device='cuda:0')
# discriminator, epoch48 : tensor(2.4374, device='cuda:0')
# generator, epoch48 : tensor(2.8789, device='cuda:0')
# discriminator, epoch49 : tensor(2.8371, device='cuda:0')
# generator, epoch49 : tensor(2.7947, device='cuda:0')
# discriminator, epoch50 : tensor(2.3706, device='cuda:0')
# generator, epoch50 : tensor(2.9502, device='cuda:0')
# discriminator, epoch51 : tensor(2.8966, device='cuda:0')
# generator, epoch51 : tensor(2.7550, device='cuda:0')
# discriminator, epoch52 : tensor(2.4438, device='cuda:0')
# generator, epoch52 : tensor(2.8184, device='cuda:0')
# discriminator, epoch53 : tensor(2.3975, device='cuda:0')
# generator, epoch53 : tensor(2.8597, device='cuda:0')
# discriminator, epoch54 : tensor(2.3691, device='cuda:0')
# generator, epoch54 : tensor(2.8880, device='cuda:0')
# discriminator, epoch55 : tensor(2.7150, device='cuda:0')
# generator, epoch55 : tensor(2.8659, device='cuda:0')
# discriminator, epoch56 : tensor(2.3919, device='cuda:0')
# generator, epoch56 : tensor(2.8258, device='cuda:0')
# discriminator, epoch57 : tensor(2.6475, device='cuda:0')
# generator, epoch57 : tensor(2.8174, device='cuda:0')
# discriminator, epoch58 : tensor(2.3995, device='cuda:0')
# generator, epoch58 : tensor(2.7915, device='cuda:0')
# discriminator, epoch59 : tensor(2.3287, device='cuda:0')
# generator, epoch59 : tensor(2.8901, device='cuda:0')
# discriminator, epoch60 : tensor(2.3450, device='cuda:0')
# generator, epoch60 : tensor(2.8606, device='cuda:0')
# discriminator, epoch61 : tensor(2.2115, device='cuda:0')
# generator, epoch61 : tensor(3.0631, device='cuda:0')
# discriminator, epoch62 : tensor(2.4910, device='cuda:0')
# generator, epoch62 : tensor(3.0487, device='cuda:0')
# discriminator, epoch63 : tensor(2.3344, device='cuda:0')
# generator, epoch63 : tensor(2.8321, device='cuda:0')
# discriminator, epoch64 : tensor(2.5123, device='cuda:0')
# generator, epoch64 : tensor(2.9758, device='cuda:0')
# discriminator, epoch65 : tensor(2.2555, device='cuda:0')
# generator, epoch65 : tensor(2.9420, device='cuda:0')
# discriminator, epoch66 : tensor(2.1240, device='cuda:0')
# generator, epoch66 : tensor(3.1591, device='cuda:0')
# discriminator, epoch67 : tensor(2.2058, device='cuda:0')
# generator, epoch67 : tensor(2.9975, device='cuda:0')
# discriminator, epoch68 : tensor(2.1222, device='cuda:0')
# generator, epoch68 : tensor(3.1310, device='cuda:0')
# discriminator, epoch69 : tensor(2.1011, device='cuda:0')
# generator, epoch69 : tensor(3.1528, device='cuda:0')
# discriminator, epoch70 : tensor(2.1367, device='cuda:0')
# generator, epoch70 : tensor(3.0740, device='cuda:0')
# discriminator, epoch71 : tensor(2.3993, device='cuda:0')
# generator, epoch71 : tensor(3.1224, device='cuda:0')
# discriminator, epoch72 : tensor(2.2899, device='cuda:0')
# generator, epoch72 : tensor(3.3114, device='cuda:0')
# discriminator, epoch73 : tensor(1.9794, device='cuda:0')
# generator, epoch73 : tensor(3.3376, device='cuda:0')
# discriminator, epoch74 : tensor(2.5256, device='cuda:0')
# generator, epoch74 : tensor(3.3930, device='cuda:0')
# discriminator, epoch75 : tensor(2.2205, device='cuda:0')
# generator, epoch75 : tensor(3.3548, device='cuda:0')
# discriminator, epoch76 : tensor(2.4652, device='cuda:0')
# generator, epoch76 : tensor(3.2524, device='cuda:0')
# discriminator, epoch77 : tensor(1.9599, device='cuda:0')
# generator, epoch77 : tensor(3.3572, device='cuda:0')
# discriminator, epoch78 : tensor(2.2705, device='cuda:0')
# generator, epoch78 : tensor(3.2116, device='cuda:0')
# discriminator, epoch79 : tensor(2.4172, device='cuda:0')
# generator, epoch79 : tensor(3.2907, device='cuda:0')
# discriminator, epoch80 : tensor(2.3824, device='cuda:0')
# generator, epoch80 : tensor(3.3034, device='cuda:0')
# discriminator, epoch81 : tensor(1.9632, device='cuda:0')
# generator, epoch81 : tensor(3.3213, device='cuda:0')
# discriminator, epoch82 : tensor(2.4557, device='cuda:0')
# generator, epoch82 : tensor(3.3649, device='cuda:0')
# discriminator, epoch83 : tensor(2.4024, device='cuda:0')
# generator, epoch83 : tensor(3.1482, device='cuda:0')
# discriminator, epoch84 : tensor(2.4643, device='cuda:0')
# generator, epoch84 : tensor(3.2241, device='cuda:0')
# discriminator, epoch85 : tensor(2.0319, device='cuda:0')
# generator, epoch85 : tensor(3.1830, device='cuda:0')
# discriminator, epoch86 : tensor(2.2618, device='cuda:0')
# generator, epoch86 : tensor(3.2969, device='cuda:0')
# discriminator, epoch87 : tensor(1.9924, device='cuda:0')
# generator, epoch87 : tensor(3.2631, device='cuda:0')
# discriminator, epoch88 : tensor(2.1189, device='cuda:0')
# generator, epoch88 : tensor(3.4020, device='cuda:0')
# discriminator, epoch89 : tensor(2.2653, device='cuda:0')
# generator, epoch89 : tensor(3.1031, device='cuda:0')
# discriminator, epoch90 : tensor(2.0304, device='cuda:0')
# generator, epoch90 : tensor(3.1349, device='cuda:0')
# discriminator, epoch91 : tensor(2.0634, device='cuda:0')
# generator, epoch91 : tensor(3.0743, device='cuda:0')
# discriminator, epoch92 : tensor(2.0682, device='cuda:0')
# generator, epoch92 : tensor(3.0586, device='cuda:0')
# discriminator, epoch93 : tensor(2.2358, device='cuda:0')
# generator, epoch93 : tensor(3.2225, device='cuda:0')
# discriminator, epoch94 : tensor(1.8383, device='cuda:0')
# generator, epoch94 : tensor(3.4641, device='cuda:0')
# discriminator, epoch95 : tensor(2.2387, device='cuda:0')
# generator, epoch95 : tensor(3.0644, device='cuda:0')
# discriminator, epoch96 : tensor(2.3507, device='cuda:0')
# generator, epoch96 : tensor(3.2432, device='cuda:0')
# discriminator, epoch97 : tensor(2.0875, device='cuda:0')
# generator, epoch97 : tensor(3.4726, device='cuda:0')
# discriminator, epoch98 : tensor(1.8606, device='cuda:0')
# generator, epoch98 : tensor(3.4094, device='cuda:0')
# discriminator, epoch99 : tensor(1.9032, device='cuda:0')
# generator, epoch99 : tensor(3.2969, device='cuda:0')
# discriminator, epoch100 : tensor(1.8897, device='cuda:0')
# generator, epoch100 : tensor(3.3351, device='cuda:0')
# discriminator, epoch101 : tensor(1.7874, device='cuda:0')
# generator, epoch101 : tensor(3.5158, device='cuda:0')
# discriminator, epoch102 : tensor(2.0114, device='cuda:0')
# generator, epoch102 : tensor(3.4648, device='cuda:0')
# discriminator, epoch103 : tensor(1.8569, device='cuda:0')
# generator, epoch103 : tensor(3.7971, device='cuda:0')
# discriminator, epoch104 : tensor(1.8721, device='cuda:0')
# generator, epoch104 : tensor(3.7446, device='cuda:0')
# discriminator, epoch105 : tensor(1.8305, device='cuda:0')
# generator, epoch105 : tensor(3.8023, device='cuda:0')
# discriminator, epoch106 : tensor(1.6171, device='cuda:0')
# generator, epoch106 : tensor(3.9029, device='cuda:0')
# discriminator, epoch107 : tensor(1.6157, device='cuda:0')
# generator, epoch107 : tensor(3.8840, device='cuda:0')
# discriminator, epoch108 : tensor(1.7898, device='cuda:0')
# generator, epoch108 : tensor(4.1309, device='cuda:0')
# discriminator, epoch109 : tensor(2.0021, device='cuda:0')
# generator, epoch109 : tensor(3.8991, device='cuda:0')
# discriminator, epoch110 : tensor(1.8537, device='cuda:0')
# generator, epoch110 : tensor(3.8825, device='cuda:0')
# discriminator, epoch111 : tensor(1.4966, device='cuda:0')
# generator, epoch111 : tensor(4.1832, device='cuda:0')
# discriminator, epoch112 : tensor(1.6962, device='cuda:0')
# generator, epoch112 : tensor(4.2480, device='cuda:0')
# discriminator, epoch113 : tensor(1.6520, device='cuda:0')
# generator, epoch113 : tensor(4.1146, device='cuda:0')
# discriminator, epoch114 : tensor(1.5511, device='cuda:0')
# generator, epoch114 : tensor(4.0077, device='cuda:0')
# discriminator, epoch115 : tensor(1.7068, device='cuda:0')
# generator, epoch115 : tensor(4.1110, device='cuda:0')
# discriminator, epoch116 : tensor(1.5710, device='cuda:0')
# generator, epoch116 : tensor(3.9257, device='cuda:0')
# discriminator, epoch117 : tensor(1.6025, device='cuda:0')
# generator, epoch117 : tensor(4.1741, device='cuda:0')
# discriminator, epoch118 : tensor(1.7592, device='cuda:0')
# generator, epoch118 : tensor(4.4195, device='cuda:0')
# discriminator, epoch119 : tensor(1.4302, device='cuda:0')
# generator, epoch119 : tensor(4.2967, device='cuda:0')
# discriminator, epoch120 : tensor(1.5435, device='cuda:0')
# generator, epoch120 : tensor(4.3019, device='cuda:0')
# discriminator, epoch121 : tensor(1.6235, device='cuda:0')
# generator, epoch121 : tensor(4.2218, device='cuda:0')
# discriminator, epoch122 : tensor(1.4935, device='cuda:0')
# generator, epoch122 : tensor(4.4034, device='cuda:0')
# discriminator, epoch123 : tensor(1.4143, device='cuda:0')
# generator, epoch123 : tensor(4.2980, device='cuda:0')
# discriminator, epoch124 : tensor(1.4318, device='cuda:0')
# generator, epoch124 : tensor(4.2333, device='cuda:0')
# discriminator, epoch125 : tensor(1.3754, device='cuda:0')
# generator, epoch125 : tensor(4.3992, device='cuda:0')
# discriminator, epoch126 : tensor(1.3595, device='cuda:0')
# generator, epoch126 : tensor(4.4283, device='cuda:0')
# discriminator, epoch127 : tensor(1.4790, device='cuda:0')
# generator, epoch127 : tensor(4.3556, device='cuda:0')
# discriminator, epoch128 : tensor(1.5394, device='cuda:0')
# generator, epoch128 : tensor(4.3751, device='cuda:0')
# discriminator, epoch129 : tensor(1.3421, device='cuda:0')
# generator, epoch129 : tensor(4.4256, device='cuda:0')
# discriminator, epoch130 : tensor(1.3079, device='cuda:0')
# generator, epoch130 : tensor(4.5288, device='cuda:0')
# discriminator, epoch131 : tensor(1.5076, device='cuda:0')
# generator, epoch131 : tensor(4.4087, device='cuda:0')
# discriminator, epoch132 : tensor(1.5024, device='cuda:0')
# generator, epoch132 : tensor(4.3966, device='cuda:0')
# discriminator, epoch133 : tensor(1.4037, device='cuda:0')
# generator, epoch133 : tensor(4.5610, device='cuda:0')
# discriminator, epoch134 : tensor(1.2557, device='cuda:0')
# generator, epoch134 : tensor(4.6672, device='cuda:0')
# discriminator, epoch135 : tensor(1.2182, device='cuda:0')
# generator, epoch135 : tensor(4.8077, device='cuda:0')
# discriminator, epoch136 : tensor(1.5967, device='cuda:0')
# generator, epoch136 : tensor(4.6626, device='cuda:0')
# discriminator, epoch137 : tensor(1.3527, device='cuda:0')
# generator, epoch137 : tensor(4.7832, device='cuda:0')
# discriminator, epoch138 : tensor(1.1873, device='cuda:0')
# generator, epoch138 : tensor(4.8763, device='cuda:0')
# discriminator, epoch139 : tensor(1.2319, device='cuda:0')
# generator, epoch139 : tensor(4.6863, device='cuda:0')
# discriminator, epoch140 : tensor(1.3130, device='cuda:0')
# generator, epoch140 : tensor(4.7942, device='cuda:0')
# discriminator, epoch141 : tensor(1.2871, device='cuda:0')
# generator, epoch141 : tensor(4.9626, device='cuda:0')
# discriminator, epoch142 : tensor(1.5304, device='cuda:0')
# generator, epoch142 : tensor(4.7769, device='cuda:0')
# discriminator, epoch143 : tensor(1.2954, device='cuda:0')
# generator, epoch143 : tensor(4.8726, device='cuda:0')
# discriminator, epoch144 : tensor(1.2387, device='cuda:0')
# generator, epoch144 : tensor(5.0455, device='cuda:0')
# discriminator, epoch145 : tensor(1.1092, device='cuda:0')
# generator, epoch145 : tensor(5.1096, device='cuda:0')
# discriminator, epoch146 : tensor(1.4816, device='cuda:0')
# generator, epoch146 : tensor(4.8159, device='cuda:0')
# discriminator, epoch147 : tensor(1.0962, device='cuda:0')
# generator, epoch147 : tensor(5.1415, device='cuda:0')
# discriminator, epoch148 : tensor(1.2344, device='cuda:0')
# generator, epoch148 : tensor(4.9532, device='cuda:0')
# discriminator, epoch149 : tensor(1.1324, device='cuda:0')
# generator, epoch149 : tensor(4.9623, device='cuda:0')
# discriminator, epoch150 : tensor(1.1154, device='cuda:0')
# generator, epoch150 : tensor(5.0088, device='cuda:0')
# discriminator, epoch151 : tensor(1.0904, device='cuda:0')
# generator, epoch151 : tensor(5.1001, device='cuda:0')
# discriminator, epoch152 : tensor(1.1343, device='cuda:0')
# generator, epoch152 : tensor(4.8960, device='cuda:0')
# discriminator, epoch153 : tensor(1.2089, device='cuda:0')
# generator, epoch153 : tensor(5.0836, device='cuda:0')
# discriminator, epoch154 : tensor(1.1842, device='cuda:0')
# generator, epoch154 : tensor(5.1608, device='cuda:0')
# discriminator, epoch155 : tensor(1.1089, device='cuda:0')
# generator, epoch155 : tensor(4.9328, device='cuda:0')
# discriminator, epoch156 : tensor(1.1366, device='cuda:0')
# generator, epoch156 : tensor(4.8101, device='cuda:0')
# discriminator, epoch157 : tensor(1.1936, device='cuda:0')
# generator, epoch157 : tensor(5.0336, device='cuda:0')
# discriminator, epoch158 : tensor(1.3481, device='cuda:0')
# generator, epoch158 : tensor(5.1346, device='cuda:0')
# discriminator, epoch159 : tensor(1.0177, device='cuda:0')
# generator, epoch159 : tensor(5.2880, device='cuda:0')
# discriminator, epoch160 : tensor(1.1634, device='cuda:0')
# generator, epoch160 : tensor(5.1127, device='cuda:0')
# discriminator, epoch161 : tensor(1.0555, device='cuda:0')
# generator, epoch161 : tensor(5.0869, device='cuda:0')
# discriminator, epoch162 : tensor(1.0901, device='cuda:0')
# generator, epoch162 : tensor(4.9163, device='cuda:0')
# discriminator, epoch163 : tensor(1.0625, device='cuda:0')
# generator, epoch163 : tensor(5.0197, device='cuda:0')
# discriminator, epoch164 : tensor(0.9978, device='cuda:0')
# generator, epoch164 : tensor(5.2949, device='cuda:0')
# discriminator, epoch165 : tensor(1.1574, device='cuda:0')
# generator, epoch165 : tensor(5.0369, device='cuda:0')
# discriminator, epoch166 : tensor(1.1208, device='cuda:0')
# generator, epoch166 : tensor(5.1855, device='cuda:0')
# discriminator, epoch167 : tensor(0.9743, device='cuda:0')
# generator, epoch167 : tensor(5.3679, device='cuda:0')
# discriminator, epoch168 : tensor(0.9832, device='cuda:0')
# generator, epoch168 : tensor(5.3017, device='cuda:0')
# discriminator, epoch169 : tensor(0.9981, device='cuda:0')
# generator, epoch169 : tensor(5.2222, device='cuda:0')
# discriminator, epoch170 : tensor(0.9822, device='cuda:0')
# generator, epoch170 : tensor(5.2696, device='cuda:0')
# discriminator, epoch171 : tensor(1.0016, device='cuda:0')
# generator, epoch171 : tensor(5.1645, device='cuda:0')
# discriminator, epoch172 : tensor(1.1720, device='cuda:0')
# generator, epoch172 : tensor(5.0874, device='cuda:0')
# discriminator, epoch173 : tensor(1.1480, device='cuda:0')
# generator, epoch173 : tensor(5.1641, device='cuda:0')
# discriminator, epoch174 : tensor(1.3372, device='cuda:0')
# generator, epoch174 : tensor(4.9665, device='cuda:0')
# discriminator, epoch175 : tensor(1.1989, device='cuda:0')
# generator, epoch175 : tensor(4.8594, device='cuda:0')
# discriminator, epoch176 : tensor(1.0271, device='cuda:0')
# generator, epoch176 : tensor(5.0021, device='cuda:0')
# discriminator, epoch177 : tensor(1.0494, device='cuda:0')
# generator, epoch177 : tensor(4.8924, device='cuda:0')
# discriminator, epoch178 : tensor(1.2143, device='cuda:0')
# generator, epoch178 : tensor(4.6615, device='cuda:0')
# discriminator, epoch179 : tensor(1.1426, device='cuda:0')
# generator, epoch179 : tensor(4.9406, device='cuda:0')
# discriminator, epoch180 : tensor(1.1428, device='cuda:0')
# generator, epoch180 : tensor(4.5107, device='cuda:0')
# discriminator, epoch181 : tensor(1.1683, device='cuda:0')
# generator, epoch181 : tensor(4.7908, device='cuda:0')
# discriminator, epoch182 : tensor(1.2409, device='cuda:0')
# generator, epoch182 : tensor(4.5903, device='cuda:0')
# discriminator, epoch183 : tensor(1.1224, device='cuda:0')
# generator, epoch183 : tensor(5.0319, device='cuda:0')
# discriminator, epoch184 : tensor(1.0003, device='cuda:0')
# generator, epoch184 : tensor(5.0457, device='cuda:0')
# discriminator, epoch185 : tensor(1.1058, device='cuda:0')
# generator, epoch185 : tensor(4.9908, device='cuda:0')
# discriminator, epoch186 : tensor(1.0171, device='cuda:0')
# generator, epoch186 : tensor(4.9695, device='cuda:0')
# discriminator, epoch187 : tensor(1.0140, device='cuda:0')
# generator, epoch187 : tensor(4.9570, device='cuda:0')
# discriminator, epoch188 : tensor(1.1411, device='cuda:0')
# generator, epoch188 : tensor(4.5009, device='cuda:0')
# discriminator, epoch189 : tensor(1.0800, device='cuda:0')
# generator, epoch189 : tensor(4.6888, device='cuda:0')
# discriminator, epoch190 : tensor(1.2697, device='cuda:0')
# generator, epoch190 : tensor(5.0639, device='cuda:0')
# discriminator, epoch191 : tensor(1.0995, device='cuda:0')
# generator, epoch191 : tensor(4.9752, device='cuda:0')
# discriminator, epoch192 : tensor(0.9983, device='cuda:0')
# generator, epoch192 : tensor(4.9814, device='cuda:0')
# discriminator, epoch193 : tensor(1.0312, device='cuda:0')
# generator, epoch193 : tensor(4.8331, device='cuda:0')
# discriminator, epoch194 : tensor(1.0491, device='cuda:0')
# generator, epoch194 : tensor(5.2603, device='cuda:0')
# discriminator, epoch195 : tensor(1.0587, device='cuda:0')
# generator, epoch195 : tensor(5.2082, device='cuda:0')
# discriminator, epoch196 : tensor(1.0366, device='cuda:0')
# generator, epoch196 : tensor(5.2751, device='cuda:0')
# discriminator, epoch197 : tensor(0.9055, device='cuda:0')
# generator, epoch197 : tensor(5.3557, device='cuda:0')
# discriminator, epoch198 : tensor(0.8857, device='cuda:0')
# generator, epoch198 : tensor(5.4518, device='cuda:0')
# discriminator, epoch199 : tensor(1.0268, device='cuda:0')
# generator, epoch199 : tensor(5.2826, device='cuda:0')
# discriminator, epoch200 : tensor(0.9561, device='cuda:0')
# generator, epoch200 : tensor(5.6217, device='cuda:0')
# 79939
# discriminator, epoch201 : tensor(1.1324, device='cuda:0')
# generator, epoch201 : tensor(5.5755, device='cuda:0')
# discriminator, epoch202 : tensor(0.8323, device='cuda:0')
# generator, epoch202 : tensor(5.7178, device='cuda:0')
# discriminator, epoch203 : tensor(0.9569, device='cuda:0')
# generator, epoch203 : tensor(5.5860, device='cuda:0')
# discriminator, epoch204 : tensor(0.8319, device='cuda:0')
# generator, epoch204 : tensor(5.7204, device='cuda:0')
# discriminator, epoch205 : tensor(0.8055, device='cuda:0')
# generator, epoch205 : tensor(5.8378, device='cuda:0')
# discriminator, epoch206 : tensor(0.8147, device='cuda:0')
# generator, epoch206 : tensor(5.7500, device='cuda:0')
# discriminator, epoch207 : tensor(0.8833, device='cuda:0')
# generator, epoch207 : tensor(5.3918, device='cuda:0')
# discriminator, epoch208 : tensor(0.9466, device='cuda:0')
# generator, epoch208 : tensor(5.5922, device='cuda:0')
# discriminator, epoch209 : tensor(0.9540, device='cuda:0')
# generator, epoch209 : tensor(5.5198, device='cuda:0')
# discriminator, epoch210 : tensor(0.9993, device='cuda:0')
# generator, epoch210 : tensor(5.3214, device='cuda:0')
# discriminator, epoch211 : tensor(0.8927, device='cuda:0')
# generator, epoch211 : tensor(5.2840, device='cuda:0')
# discriminator, epoch212 : tensor(0.8871, device='cuda:0')
# generator, epoch212 : tensor(5.3005, device='cuda:0')
# discriminator, epoch213 : tensor(0.9541, device='cuda:0')
# generator, epoch213 : tensor(5.4559, device='cuda:0')
# discriminator, epoch214 : tensor(0.9155, device='cuda:0')
# generator, epoch214 : tensor(5.1723, device='cuda:0')
# discriminator, epoch215 : tensor(1.0117, device='cuda:0')
# generator, epoch215 : tensor(5.1268, device='cuda:0')
# discriminator, epoch216 : tensor(1.0634, device='cuda:0')
# generator, epoch216 : tensor(4.9126, device='cuda:0')
# discriminator, epoch217 : tensor(0.9976, device='cuda:0')
# generator, epoch217 : tensor(5.1873, device='cuda:0')
# discriminator, epoch218 : tensor(0.9708, device='cuda:0')
# generator, epoch218 : tensor(4.9152, device='cuda:0')
# discriminator, epoch219 : tensor(1.1771, device='cuda:0')
# generator, epoch219 : tensor(5.1393, device='cuda:0')
# discriminator, epoch220 : tensor(0.9551, device='cuda:0')
# generator, epoch220 : tensor(5.3728, device='cuda:0')
# discriminator, epoch221 : tensor(0.8630, device='cuda:0')
# generator, epoch221 : tensor(5.3637, device='cuda:0')
# discriminator, epoch222 : tensor(0.9384, device='cuda:0')
# generator, epoch222 : tensor(5.4226, device='cuda:0')
# discriminator, epoch223 : tensor(0.9094, device='cuda:0')
# generator, epoch223 : tensor(5.5601, device='cuda:0')
# discriminator, epoch224 : tensor(0.8239, device='cuda:0')
# generator, epoch224 : tensor(5.5521, device='cuda:0')
# discriminator, epoch225 : tensor(0.7661, device='cuda:0')
# generator, epoch225 : tensor(5.8758, device='cuda:0')
# discriminator, epoch226 : tensor(1.0349, device='cuda:0')
# generator, epoch226 : tensor(5.6579, device='cuda:0')
# discriminator, epoch227 : tensor(0.9233, device='cuda:0')
# generator, epoch227 : tensor(5.4992, device='cuda:0')
# discriminator, epoch228 : tensor(1.0039, device='cuda:0')
# generator, epoch228 : tensor(5.7451, device='cuda:0')
# discriminator, epoch229 : tensor(0.7787, device='cuda:0')
# generator, epoch229 : tensor(5.7905, device='cuda:0')
# discriminator, epoch230 : tensor(0.7793, device='cuda:0')
# generator, epoch230 : tensor(5.7618, device='cuda:0')
# discriminator, epoch231 : tensor(0.7955, device='cuda:0')
# generator, epoch231 : tensor(5.6784, device='cuda:0')
# discriminator, epoch232 : tensor(0.7439, device='cuda:0')
# generator, epoch232 : tensor(5.9429, device='cuda:0')
# discriminator, epoch233 : tensor(0.7734, device='cuda:0')
# generator, epoch233 : tensor(5.7398, device='cuda:0')
# discriminator, epoch234 : tensor(0.7321, device='cuda:0')
# generator, epoch234 : tensor(5.9702, device='cuda:0')
# discriminator, epoch235 : tensor(0.9248, device='cuda:0')
# generator, epoch235 : tensor(6.0039, device='cuda:0')
# discriminator, epoch236 : tensor(0.9326, device='cuda:0')
# generator, epoch236 : tensor(5.9225, device='cuda:0')
# discriminator, epoch237 : tensor(0.8495, device='cuda:0')
# generator, epoch237 : tensor(5.8072, device='cuda:0')
# discriminator, epoch238 : tensor(0.7680, device='cuda:0')
# generator, epoch238 : tensor(5.7123, device='cuda:0')
# discriminator, epoch239 : tensor(0.8888, device='cuda:0')
# generator, epoch239 : tensor(5.6538, device='cuda:0')
# discriminator, epoch240 : tensor(0.8749, device='cuda:0')
# generator, epoch240 : tensor(5.7118, device='cuda:0')
# discriminator, epoch241 : tensor(0.7916, device='cuda:0')
# generator, epoch241 : tensor(5.5941, device='cuda:0')
# discriminator, epoch242 : tensor(0.8021, device='cuda:0')
# generator, epoch242 : tensor(5.4991, device='cuda:0')
# discriminator, epoch243 : tensor(0.7697, device='cuda:0')
# generator, epoch243 : tensor(5.6627, device='cuda:0')
# discriminator, epoch244 : tensor(0.8978, device='cuda:0')
# generator, epoch244 : tensor(5.5350, device='cuda:0')
# discriminator, epoch245 : tensor(0.7834, device='cuda:0')
# generator, epoch245 : tensor(5.5778, device='cuda:0')
# discriminator, epoch246 : tensor(0.7711, device='cuda:0')
# generator, epoch246 : tensor(5.6326, device='cuda:0')
# discriminator, epoch247 : tensor(0.7610, device='cuda:0')
# generator, epoch247 : tensor(5.6792, device='cuda:0')
# discriminator, epoch248 : tensor(0.8562, device='cuda:0')
# generator, epoch248 : tensor(5.7409, device='cuda:0')
# discriminator, epoch249 : tensor(0.7673, device='cuda:0')
# generator, epoch249 : tensor(5.6252, device='cuda:0')
# discriminator, epoch250 : tensor(0.8733, device='cuda:0')
# generator, epoch250 : tensor(5.6187, device='cuda:0')
# discriminator, epoch251 : tensor(0.7404, device='cuda:0')
# generator, epoch251 : tensor(5.7821, device='cuda:0')
# discriminator, epoch252 : tensor(0.8429, device='cuda:0')
# generator, epoch252 : tensor(5.7745, device='cuda:0')
# discriminator, epoch253 : tensor(0.8153, device='cuda:0')
# generator, epoch253 : tensor(5.9259, device='cuda:0')
# discriminator, epoch254 : tensor(0.8726, device='cuda:0')
# generator, epoch254 : tensor(5.5395, device='cuda:0')
# discriminator, epoch255 : tensor(0.9656, device='cuda:0')
# generator, epoch255 : tensor(5.4853, device='cuda:0')
# discriminator, epoch256 : tensor(0.7210, device='cuda:0')
# generator, epoch256 : tensor(5.8470, device='cuda:0')
# discriminator, epoch257 : tensor(0.8519, device='cuda:0')
# generator, epoch257 : tensor(5.6173, device='cuda:0')
# discriminator, epoch258 : tensor(0.7262, device='cuda:0')
# generator, epoch258 : tensor(5.8123, device='cuda:0')
# discriminator, epoch259 : tensor(0.8252, device='cuda:0')
# generator, epoch259 : tensor(5.7409, device='cuda:0')
# discriminator, epoch260 : tensor(0.7633, device='cuda:0')
# generator, epoch260 : tensor(5.5834, device='cuda:0')
# discriminator, epoch261 : tensor(0.7335, device='cuda:0')
# generator, epoch261 : tensor(5.7443, device='cuda:0')
# discriminator, epoch262 : tensor(0.7913, device='cuda:0')
# generator, epoch262 : tensor(5.8807, device='cuda:0')
# discriminator, epoch263 : tensor(0.7909, device='cuda:0')
# generator, epoch263 : tensor(5.9241, device='cuda:0')
# discriminator, epoch264 : tensor(0.7739, device='cuda:0')
# generator, epoch264 : tensor(5.9777, device='cuda:0')
# discriminator, epoch265 : tensor(0.7235, device='cuda:0')
# generator, epoch265 : tensor(5.7700, device='cuda:0')
# discriminator, epoch266 : tensor(0.6909, device='cuda:0')
# generator, epoch266 : tensor(5.9627, device='cuda:0')
# discriminator, epoch267 : tensor(0.7965, device='cuda:0')
# generator, epoch267 : tensor(5.7827, device='cuda:0')
# discriminator, epoch268 : tensor(0.6795, device='cuda:0')
# generator, epoch268 : tensor(6.0197, device='cuda:0')
# discriminator, epoch269 : tensor(0.8429, device='cuda:0')
# generator, epoch269 : tensor(6.1054, device='cuda:0')
# discriminator, epoch270 : tensor(0.8300, device='cuda:0')
# generator, epoch270 : tensor(6.1413, device='cuda:0')
# discriminator, epoch271 : tensor(0.6618, device='cuda:0')
# generator, epoch271 : tensor(6.1087, device='cuda:0')
# discriminator, epoch272 : tensor(0.7399, device='cuda:0')
# generator, epoch272 : tensor(6.1965, device='cuda:0')
# discriminator, epoch273 : tensor(0.6412, device='cuda:0')
# generator, epoch273 : tensor(6.2567, device='cuda:0')
# discriminator, epoch274 : tensor(0.7366, device='cuda:0')
# generator, epoch274 : tensor(6.1238, device='cuda:0')
# discriminator, epoch275 : tensor(0.6051, device='cuda:0')
# generator, epoch275 : tensor(6.4857, device='cuda:0')
# discriminator, epoch276 : tensor(0.6476, device='cuda:0')
# generator, epoch276 : tensor(6.1890, device='cuda:0')
# discriminator, epoch277 : tensor(0.6352, device='cuda:0')
# generator, epoch277 : tensor(6.2626, device='cuda:0')
# discriminator, epoch278 : tensor(0.6555, device='cuda:0')
# generator, epoch278 : tensor(6.1042, device='cuda:0')
# discriminator, epoch279 : tensor(0.8060, device='cuda:0')
# generator, epoch279 : tensor(6.0999, device='cuda:0')
# discriminator, epoch280 : tensor(0.6632, device='cuda:0')
# generator, epoch280 : tensor(6.0206, device='cuda:0')
# discriminator, epoch281 : tensor(0.7464, device='cuda:0')
# generator, epoch281 : tensor(6.0086, device='cuda:0')
# discriminator, epoch282 : tensor(0.6442, device='cuda:0')
# generator, epoch282 : tensor(6.1349, device='cuda:0')
# discriminator, epoch283 : tensor(0.7766, device='cuda:0')
# generator, epoch283 : tensor(6.1956, device='cuda:0')
# discriminator, epoch284 : tensor(0.7157, device='cuda:0')
# generator, epoch284 : tensor(6.1588, device='cuda:0')
# discriminator, epoch285 : tensor(0.6227, device='cuda:0')
# generator, epoch285 : tensor(6.2640, device='cuda:0')
# discriminator, epoch286 : tensor(0.6804, device='cuda:0')
# generator, epoch286 : tensor(6.3898, device='cuda:0')
# discriminator, epoch287 : tensor(0.6071, device='cuda:0')
# generator, epoch287 : tensor(6.3631, device='cuda:0')
# discriminator, epoch288 : tensor(0.6827, device='cuda:0')
# generator, epoch288 : tensor(6.3178, device='cuda:0')
# discriminator, epoch289 : tensor(0.7030, device='cuda:0')
# generator, epoch289 : tensor(6.6362, device='cuda:0')
# discriminator, epoch290 : tensor(0.6363, device='cuda:0')
# generator, epoch290 : tensor(6.6439, device='cuda:0')
# discriminator, epoch291 : tensor(0.5672, device='cuda:0')
# generator, epoch291 : tensor(6.6362, device='cuda:0')
# discriminator, epoch292 : tensor(0.6211, device='cuda:0')
# generator, epoch292 : tensor(6.6967, device='cuda:0')
# discriminator, epoch293 : tensor(0.5601, device='cuda:0')
# generator, epoch293 : tensor(6.6775, device='cuda:0')
# discriminator, epoch294 : tensor(0.5635, device='cuda:0')
# generator, epoch294 : tensor(6.6424, device='cuda:0')
# discriminator, epoch295 : tensor(0.5336, device='cuda:0')
# generator, epoch295 : tensor(6.9052, device='cuda:0')
# discriminator, epoch296 : tensor(0.5821, device='cuda:0')
# generator, epoch296 : tensor(6.4667, device='cuda:0')
# discriminator, epoch297 : tensor(0.5393, device='cuda:0')
# generator, epoch297 : tensor(6.8163, device='cuda:0')
# discriminator, epoch298 : tensor(0.5389, device='cuda:0')
# generator, epoch298 : tensor(6.7922, device='cuda:0')
# discriminator, epoch299 : tensor(0.5490, device='cuda:0')
# generator, epoch299 : tensor(6.7244, device='cuda:0')
# discriminator, epoch300 : tensor(0.5216, device='cuda:0')
# generator, epoch300 : tensor(6.9124, device='cuda:0')
# discriminator, epoch301 : tensor(0.5669, device='cuda:0')
# generator, epoch301 : tensor(7.0707, device='cuda:0')
# discriminator, epoch302 : tensor(0.5411, device='cuda:0')
# generator, epoch302 : tensor(6.7465, device='cuda:0')
# discriminator, epoch303 : tensor(0.5445, device='cuda:0')
# generator, epoch303 : tensor(6.6901, device='cuda:0')
# discriminator, epoch304 : tensor(0.5076, device='cuda:0')
# generator, epoch304 : tensor(6.9981, device='cuda:0')
# discriminator, epoch305 : tensor(0.5152, device='cuda:0')
# generator, epoch305 : tensor(6.9257, device='cuda:0')
# discriminator, epoch306 : tensor(0.6591, device='cuda:0')
# generator, epoch306 : tensor(6.7325, device='cuda:0')
# discriminator, epoch307 : tensor(0.6596, device='cuda:0')
# generator, epoch307 : tensor(6.6780, device='cuda:0')
# discriminator, epoch308 : tensor(0.5288, device='cuda:0')
# generator, epoch308 : tensor(6.7728, device='cuda:0')
# discriminator, epoch309 : tensor(0.5790, device='cuda:0')
# generator, epoch309 : tensor(6.9031, device='cuda:0')
# discriminator, epoch310 : tensor(0.5058, device='cuda:0')
# generator, epoch310 : tensor(6.9621, device='cuda:0')
# discriminator, epoch311 : tensor(0.5989, device='cuda:0')
# generator, epoch311 : tensor(6.9757, device='cuda:0')
# discriminator, epoch312 : tensor(0.6369, device='cuda:0')
# generator, epoch312 : tensor(6.9859, device='cuda:0')
# discriminator, epoch313 : tensor(0.6441, device='cuda:0')
# generator, epoch313 : tensor(6.8929, device='cuda:0')
# discriminator, epoch314 : tensor(0.5203, device='cuda:0')
# generator, epoch314 : tensor(6.8062, device='cuda:0')
# discriminator, epoch315 : tensor(0.5000, device='cuda:0')
# generator, epoch315 : tensor(6.9822, device='cuda:0')
# discriminator, epoch316 : tensor(0.5132, device='cuda:0')
# generator, epoch316 : tensor(6.8511, device='cuda:0')
# discriminator, epoch317 : tensor(0.5027, device='cuda:0')
# generator, epoch317 : tensor(6.9285, device='cuda:0')
# discriminator, epoch318 : tensor(0.5512, device='cuda:0')
# generator, epoch318 : tensor(7.0516, device='cuda:0')
# discriminator, epoch319 : tensor(0.5082, device='cuda:0')
# generator, epoch319 : tensor(6.8663, device='cuda:0')
# discriminator, epoch320 : tensor(0.5047, device='cuda:0')
# generator, epoch320 : tensor(6.9030, device='cuda:0')
# discriminator, epoch321 : tensor(0.5438, device='cuda:0')
# generator, epoch321 : tensor(7.0794, device='cuda:0')
# discriminator, epoch322 : tensor(0.5666, device='cuda:0')
# generator, epoch322 : tensor(6.8721, device='cuda:0')
# discriminator, epoch323 : tensor(0.5688, device='cuda:0')
# generator, epoch323 : tensor(6.8165, device='cuda:0')
# discriminator, epoch324 : tensor(0.5153, device='cuda:0')
# generator, epoch324 : tensor(6.7722, device='cuda:0')
# discriminator, epoch325 : tensor(0.6210, device='cuda:0')
# generator, epoch325 : tensor(6.8576, device='cuda:0')
# discriminator, epoch326 : tensor(0.6068, device='cuda:0')
# generator, epoch326 : tensor(6.7196, device='cuda:0')
# discriminator, epoch327 : tensor(0.4985, device='cuda:0')
# generator, epoch327 : tensor(6.9017, device='cuda:0')
# discriminator, epoch328 : tensor(0.5199, device='cuda:0')
# generator, epoch328 : tensor(6.7292, device='cuda:0')
# discriminator, epoch329 : tensor(0.4875, device='cuda:0')
# generator, epoch329 : tensor(6.9877, device='cuda:0')
# discriminator, epoch330 : tensor(0.4880, device='cuda:0')
# generator, epoch330 : tensor(6.9841, device='cuda:0')
# discriminator, epoch331 : tensor(0.4912, device='cuda:0')
# generator, epoch331 : tensor(6.9366, device='cuda:0')
# discriminator, epoch332 : tensor(0.5054, device='cuda:0')
# generator, epoch332 : tensor(6.8192, device='cuda:0')
# discriminator, epoch333 : tensor(0.4445, device='cuda:0')
# generator, epoch333 : tensor(7.3733, device='cuda:0')
# discriminator, epoch334 : tensor(0.5310, device='cuda:0')
# generator, epoch334 : tensor(7.2957, device='cuda:0')
# discriminator, epoch335 : tensor(0.5257, device='cuda:0')
# generator, epoch335 : tensor(7.3374, device='cuda:0')
# discriminator, epoch336 : tensor(0.4956, device='cuda:0')
# generator, epoch336 : tensor(7.4514, device='cuda:0')
# discriminator, epoch337 : tensor(0.5907, device='cuda:0')
# generator, epoch337 : tensor(7.0273, device='cuda:0')
# discriminator, epoch338 : tensor(0.5104, device='cuda:0')
# generator, epoch338 : tensor(7.4103, device='cuda:0')
# discriminator, epoch339 : tensor(0.4481, device='cuda:0')
# generator, epoch339 : tensor(7.3125, device='cuda:0')
# discriminator, epoch340 : tensor(0.4357, device='cuda:0')
# generator, epoch340 : tensor(7.4354, device='cuda:0')
# discriminator, epoch341 : tensor(0.4302, device='cuda:0')
# generator, epoch341 : tensor(7.4825, device='cuda:0')
# discriminator, epoch342 : tensor(0.4931, device='cuda:0')
# generator, epoch342 : tensor(7.4033, device='cuda:0')
# discriminator, epoch343 : tensor(0.5252, device='cuda:0')
# generator, epoch343 : tensor(7.5931, device='cuda:0')
# discriminator, epoch344 : tensor(0.5273, device='cuda:0')
# generator, epoch344 : tensor(7.5279, device='cuda:0')
# discriminator, epoch345 : tensor(0.4263, device='cuda:0')
# generator, epoch345 : tensor(7.4990, device='cuda:0')
# discriminator, epoch346 : tensor(0.4114, device='cuda:0')
# generator, epoch346 : tensor(7.6781, device='cuda:0')
# discriminator, epoch347 : tensor(0.4375, device='cuda:0')
# generator, epoch347 : tensor(7.3526, device='cuda:0')
# discriminator, epoch348 : tensor(0.4768, device='cuda:0')
# generator, epoch348 : tensor(7.4963, device='cuda:0')
# discriminator, epoch349 : tensor(0.4175, device='cuda:0')
# generator, epoch349 : tensor(7.5668, device='cuda:0')
# discriminator, epoch350 : tensor(0.4267, device='cuda:0')
# generator, epoch350 : tensor(7.4662, device='cuda:0')
# discriminator, epoch351 : tensor(0.4254, device='cuda:0')
# generator, epoch351 : tensor(7.4519, device='cuda:0')
# discriminator, epoch352 : tensor(0.4978, device='cuda:0')
# generator, epoch352 : tensor(7.3941, device='cuda:0')
# discriminator, epoch353 : tensor(0.4365, device='cuda:0')
# generator, epoch353 : tensor(7.3294, device='cuda:0')
# discriminator, epoch354 : tensor(0.4296, device='cuda:0')
# generator, epoch354 : tensor(7.3861, device='cuda:0')
# discriminator, epoch355 : tensor(0.4448, device='cuda:0')
# generator, epoch355 : tensor(7.2154, device='cuda:0')
# discriminator, epoch356 : tensor(0.4314, device='cuda:0')
# generator, epoch356 : tensor(7.3676, device='cuda:0')
# discriminator, epoch357 : tensor(0.4859, device='cuda:0')
# generator, epoch357 : tensor(7.4824, device='cuda:0')
# discriminator, epoch358 : tensor(0.4203, device='cuda:0')
# generator, epoch358 : tensor(7.4580, device='cuda:0')
# discriminator, epoch359 : tensor(0.4132, device='cuda:0')
# generator, epoch359 : tensor(7.5275, device='cuda:0')
# discriminator, epoch360 : tensor(0.4547, device='cuda:0')
# generator, epoch360 : tensor(7.0774, device='cuda:0')
# discriminator, epoch361 : tensor(0.4515, device='cuda:0')
# generator, epoch361 : tensor(7.0973, device='cuda:0')
# discriminator, epoch362 : tensor(0.4372, device='cuda:0')
# generator, epoch362 : tensor(7.2948, device='cuda:0')
# discriminator, epoch363 : tensor(0.4955, device='cuda:0')
# generator, epoch363 : tensor(7.3260, device='cuda:0')
# discriminator, epoch364 : tensor(0.4827, device='cuda:0')
# generator, epoch364 : tensor(7.3573, device='cuda:0')
# discriminator, epoch365 : tensor(0.4185, device='cuda:0')
# generator, epoch365 : tensor(7.4315, device='cuda:0')
# discriminator, epoch366 : tensor(0.4597, device='cuda:0')
# generator, epoch366 : tensor(7.6240, device='cuda:0')
# discriminator, epoch367 : tensor(0.5172, device='cuda:0')
# generator, epoch367 : tensor(7.4419, device='cuda:0')
# discriminator, epoch368 : tensor(0.5095, device='cuda:0')
# generator, epoch368 : tensor(7.4914, device='cuda:0')
# discriminator, epoch369 : tensor(0.4023, device='cuda:0')
# generator, epoch369 : tensor(7.5605, device='cuda:0')
# discriminator, epoch370 : tensor(0.4874, device='cuda:0')
# generator, epoch370 : tensor(7.2657, device='cuda:0')
# discriminator, epoch371 : tensor(0.4962, device='cuda:0')
# generator, epoch371 : tensor(7.5406, device='cuda:0')
# discriminator, epoch372 : tensor(0.3935, device='cuda:0')
# generator, epoch372 : tensor(7.6562, device='cuda:0')
# discriminator, epoch373 : tensor(0.4092, device='cuda:0')
# generator, epoch373 : tensor(7.4930, device='cuda:0')
# discriminator, epoch374 : tensor(0.3985, device='cuda:0')
# generator, epoch374 : tensor(7.5944, device='cuda:0')
# discriminator, epoch375 : tensor(0.4527, device='cuda:0')
# generator, epoch375 : tensor(7.5784, device='cuda:0')
# discriminator, epoch376 : tensor(0.3764, device='cuda:0')
# generator, epoch376 : tensor(7.8522, device='cuda:0')
# discriminator, epoch377 : tensor(0.3845, device='cuda:0')
# generator, epoch377 : tensor(7.7228, device='cuda:0')
# discriminator, epoch378 : tensor(0.4435, device='cuda:0')
# generator, epoch378 : tensor(7.6853, device='cuda:0')
# discriminator, epoch379 : tensor(0.4666, device='cuda:0')
# generator, epoch379 : tensor(7.7385, device='cuda:0')
# discriminator, epoch380 : tensor(0.4296, device='cuda:0')
# generator, epoch380 : tensor(7.7866, device='cuda:0')
# discriminator, epoch381 : tensor(0.4417, device='cuda:0')
# generator, epoch381 : tensor(7.6267, device='cuda:0')
# discriminator, epoch382 : tensor(0.3959, device='cuda:0')
# generator, epoch382 : tensor(7.5618, device='cuda:0')
# discriminator, epoch383 : tensor(0.4358, device='cuda:0')
# generator, epoch383 : tensor(7.6893, device='cuda:0')
# discriminator, epoch384 : tensor(0.3800, device='cuda:0')
# generator, epoch384 : tensor(7.7514, device='cuda:0')
# discriminator, epoch385 : tensor(0.4290, device='cuda:0')
# generator, epoch385 : tensor(7.7066, device='cuda:0')
# discriminator, epoch386 : tensor(0.3664, device='cuda:0')
# generator, epoch386 : tensor(7.8937, device='cuda:0')
# discriminator, epoch387 : tensor(0.4389, device='cuda:0')
# generator, epoch387 : tensor(7.9781, device='cuda:0')
# discriminator, epoch388 : tensor(0.3664, device='cuda:0')
# generator, epoch388 : tensor(7.8908, device='cuda:0')
# discriminator, epoch389 : tensor(0.4160, device='cuda:0')
# generator, epoch389 : tensor(7.8065, device='cuda:0')
# discriminator, epoch390 : tensor(0.4499, device='cuda:0')
# generator, epoch390 : tensor(7.7827, device='cuda:0')
# discriminator, epoch391 : tensor(0.3978, device='cuda:0')
# generator, epoch391 : tensor(8.0124, device='cuda:0')
# discriminator, epoch392 : tensor(0.4070, device='cuda:0')
# generator, epoch392 : tensor(7.8785, device='cuda:0')
# discriminator, epoch393 : tensor(0.3635, device='cuda:0')
# generator, epoch393 : tensor(7.8946, device='cuda:0')
# discriminator, epoch394 : tensor(0.3921, device='cuda:0')
# generator, epoch394 : tensor(8.1798, device='cuda:0')
# discriminator, epoch395 : tensor(0.3581, device='cuda:0')
# generator, epoch395 : tensor(7.9722, device='cuda:0')
# discriminator, epoch396 : tensor(0.3670, device='cuda:0')
# generator, epoch396 : tensor(7.8360, device='cuda:0')
# discriminator, epoch397 : tensor(0.4223, device='cuda:0')
# generator, epoch397 : tensor(8.0528, device='cuda:0')
# discriminator, epoch398 : tensor(0.4158, device='cuda:0')
# generator, epoch398 : tensor(8.1229, device='cuda:0')
# discriminator, epoch399 : tensor(0.3586, device='cuda:0')
# generator, epoch399 : tensor(7.9199, device='cuda:0')
# discriminator, epoch400 : tensor(0.3421, device='cuda:0')
# generator, epoch400 : tensor(8.1296, device='cuda:0')
# 83616
# discriminator, epoch401 : tensor(0.4191, device='cuda:0')
# generator, epoch401 : tensor(8.0212, device='cuda:0')
# discriminator, epoch402 : tensor(0.3338, device='cuda:0')
# generator, epoch402 : tensor(8.2345, device='cuda:0')
# discriminator, epoch403 : tensor(0.3730, device='cuda:0')
# generator, epoch403 : tensor(8.4241, device='cuda:0')
# discriminator, epoch404 : tensor(0.3427, device='cuda:0')
# generator, epoch404 : tensor(8.1251, device='cuda:0')
# discriminator, epoch405 : tensor(0.4000, device='cuda:0')
# generator, epoch405 : tensor(8.2221, device='cuda:0')
# discriminator, epoch406 : tensor(0.3714, device='cuda:0')
# generator, epoch406 : tensor(8.2150, device='cuda:0')
# discriminator, epoch407 : tensor(0.3215, device='cuda:0')
# generator, epoch407 : tensor(8.3983, device='cuda:0')
# discriminator, epoch408 : tensor(0.3698, device='cuda:0')
# generator, epoch408 : tensor(8.3689, device='cuda:0')
# discriminator, epoch409 : tensor(0.3673, device='cuda:0')
# generator, epoch409 : tensor(8.2589, device='cuda:0')
# discriminator, epoch410 : tensor(0.3618, device='cuda:0')
# generator, epoch410 : tensor(8.4585, device='cuda:0')
# discriminator, epoch411 : tensor(0.3712, device='cuda:0')
# generator, epoch411 : tensor(8.5565, device='cuda:0')
# discriminator, epoch412 : tensor(0.3105, device='cuda:0')
# generator, epoch412 : tensor(8.5267, device='cuda:0')
# discriminator, epoch413 : tensor(0.3777, device='cuda:0')
# generator, epoch413 : tensor(8.3891, device='cuda:0')
# discriminator, epoch414 : tensor(0.3111, device='cuda:0')
# generator, epoch414 : tensor(8.5107, device='cuda:0')
# discriminator, epoch415 : tensor(0.3174, device='cuda:0')
# generator, epoch415 : tensor(8.3991, device='cuda:0')
# discriminator, epoch416 : tensor(0.3679, device='cuda:0')
# generator, epoch416 : tensor(8.2711, device='cuda:0')
# discriminator, epoch417 : tensor(0.3296, device='cuda:0')
# generator, epoch417 : tensor(8.1950, device='cuda:0')
# discriminator, epoch418 : tensor(0.3236, device='cuda:0')
# generator, epoch418 : tensor(8.2707, device='cuda:0')
# discriminator, epoch419 : tensor(0.3752, device='cuda:0')
# generator, epoch419 : tensor(8.0831, device='cuda:0')
# discriminator, epoch420 : tensor(0.3696, device='cuda:0')
# generator, epoch420 : tensor(8.1335, device='cuda:0')
# discriminator, epoch421 : tensor(0.3406, device='cuda:0')
# generator, epoch421 : tensor(8.0107, device='cuda:0')
# discriminator, epoch422 : tensor(0.3521, device='cuda:0')
# generator, epoch422 : tensor(7.8482, device='cuda:0')
# discriminator, epoch423 : tensor(0.3834, device='cuda:0')
# generator, epoch423 : tensor(8.0065, device='cuda:0')
# discriminator, epoch424 : tensor(0.3643, device='cuda:0')
# generator, epoch424 : tensor(7.6973, device='cuda:0')
# ...
# generator, epoch964 : tensor(11.5585, device='cuda:0')
# discriminator, epoch965 : tensor(0.0899, device='cuda:0')
# generator, epoch965 : tensor(11.6416, device='cuda:0')
# discriminator, epoch966 : tensor(0.0904, device='cuda:0')
# generator, epoch966 : tensor(11.6082, device='cuda:0')
# discriminator, epoch967 : tensor(0.0929, device='cuda:0')
# generator, epoch967 : tensor(11.8688, device='cuda:0')
# discriminator, epoch968 : tensor(0.0854, device='cuda:0')
# generator, epoch968 : tensor(11.8432, device='cuda:0')
# discriminator, epoch969 : tensor(0.1019, device='cuda:0')
# generator, epoch969 : tensor(11.5756, device='cuda:0')
# discriminator, epoch970 : tensor(0.0953, device='cuda:0')
# generator, epoch970 : tensor(11.8993, device='cuda:0')
# discriminator, epoch971 : tensor(0.1009, device='cuda:0')
# generator, epoch971 : tensor(11.4646, device='cuda:0')
# discriminator, epoch972 : tensor(0.0878, device='cuda:0')
# generator, epoch972 : tensor(11.7222, device='cuda:0')
# discriminator, epoch973 : tensor(0.0932, device='cuda:0')
# generator, epoch973 : tensor(11.8273, device='cuda:0')
# discriminator, epoch974 : tensor(0.1010, device='cuda:0')
# generator, epoch974 : tensor(12.0128, device='cuda:0')
# discriminator, epoch975 : tensor(0.0830, device='cuda:0')
# generator, epoch975 : tensor(11.9650, device='cuda:0')
# discriminator, epoch976 : tensor(0.0841, device='cuda:0')
# generator, epoch976 : tensor(11.9145, device='cuda:0')
# discriminator, epoch977 : tensor(0.0821, device='cuda:0')
# generator, epoch977 : tensor(11.9972, device='cuda:0')
# discriminator, epoch978 : tensor(0.0846, device='cuda:0')
# generator, epoch978 : tensor(11.8620, device='cuda:0')
# discriminator, epoch979 : tensor(0.1015, device='cuda:0')
# generator, epoch979 : tensor(11.9223, device='cuda:0')
# discriminator, epoch980 : tensor(0.0938, device='cuda:0')
# generator, epoch980 : tensor(11.9261, device='cuda:0')
# discriminator, epoch981 : tensor(0.0884, device='cuda:0')
# generator, epoch981 : tensor(12.2075, device='cuda:0')
# discriminator, epoch982 : tensor(0.0995, device='cuda:0')
# generator, epoch982 : tensor(11.9775, device='cuda:0')
# discriminator, epoch983 : tensor(0.0777, device='cuda:0')
# generator, epoch983 : tensor(12.2271, device='cuda:0')
# discriminator, epoch984 : tensor(0.0891, device='cuda:0')
# generator, epoch984 : tensor(12.1465, device='cuda:0')
# discriminator, epoch985 : tensor(0.0876, device='cuda:0')
# generator, epoch985 : tensor(12.2081, device='cuda:0')
# discriminator, epoch986 : tensor(0.0956, device='cuda:0')
# generator, epoch986 : tensor(12.1285, device='cuda:0')
# discriminator, epoch987 : tensor(0.0790, device='cuda:0')
# generator, epoch987 : tensor(12.1381, device='cuda:0')
# discriminator, epoch988 : tensor(0.0980, device='cuda:0')
# generator, epoch988 : tensor(11.9666, device='cuda:0')
# discriminator, epoch989 : tensor(0.0798, device='cuda:0')
# generator, epoch989 : tensor(12.0957, device='cuda:0')
# discriminator, epoch990 : tensor(0.0897, device='cuda:0')
# generator, epoch990 : tensor(12.0351, device='cuda:0')
# discriminator, epoch991 : tensor(0.0786, device='cuda:0')
# generator, epoch991 : tensor(12.1594, device='cuda:0')
# discriminator, epoch992 : tensor(0.0883, device='cuda:0')
# generator, epoch992 : tensor(12.0901, device='cuda:0')
# discriminator, epoch993 : tensor(0.0890, device='cuda:0')
# generator, epoch993 : tensor(12.0394, device='cuda:0')
# discriminator, epoch994 : tensor(0.0770, device='cuda:0')
# generator, epoch994 : tensor(12.2340, device='cuda:0')
# discriminator, epoch995 : tensor(0.0778, device='cuda:0')
# generator, epoch995 : tensor(12.1838, device='cuda:0')
# discriminator, epoch996 : tensor(0.0769, device='cuda:0')
# generator, epoch996 : tensor(12.2373, device='cuda:0')
# discriminator, epoch997 : tensor(0.0863, device='cuda:0')
# generator, epoch997 : tensor(12.1456, device='cuda:0')
# discriminator, epoch998 : tensor(0.0783, device='cuda:0')
# generator, epoch998 : tensor(12.1556, device='cuda:0')
# discriminator, epoch999 : tensor(0.0877, device='cuda:0')
# generator, epoch999 : tensor(12.4535, device='cuda:0')
# discriminator, epoch1000 : tensor(0.0774, device='cuda:0')
# generator, epoch1000 : tensor(12.1857, device='cuda:0')
# 60437
# discriminator, epoch1001 : tensor(0.0805, device='cuda:0')
# generator, epoch1001 : tensor(12.4677, device='cuda:0')
# discriminator, epoch1002 : tensor(0.0886, device='cuda:0')
# generator, epoch1002 : tensor(12.3749, device='cuda:0')
# discriminator, epoch1003 : tensor(0.0779, device='cuda:0')
# generator, epoch1003 : tensor(12.6099, device='cuda:0')
# discriminator, epoch1004 : tensor(0.0714, device='cuda:0')
# generator, epoch1004 : tensor(12.5437, device='cuda:0')
# discriminator, epoch1005 : tensor(0.0754, device='cuda:0')
# generator, epoch1005 : tensor(12.2891, device='cuda:0')
# discriminator, epoch1006 : tensor(0.0860, device='cuda:0')
# generator, epoch1006 : tensor(12.4943, device='cuda:0')
# discriminator, epoch1007 : tensor(0.0722, device='cuda:0')
# generator, epoch1007 : tensor(12.4821, device='cuda:0')
# discriminator, epoch1008 : tensor(0.0809, device='cuda:0')
# generator, epoch1008 : tensor(12.3903, device='cuda:0')
# discriminator, epoch1009 : tensor(0.0814, device='cuda:0')
# generator, epoch1009 : tensor(12.3515, device='cuda:0')
# discriminator, epoch1010 : tensor(0.0781, device='cuda:0')
# generator, epoch1010 : tensor(12.1178, device='cuda:0')
# discriminator, epoch1011 : tensor(0.0753, device='cuda:0')
# generator, epoch1011 : tensor(12.2676, device='cuda:0')
# discriminator, epoch1012 : tensor(0.0783, device='cuda:0')
# generator, epoch1012 : tensor(12.5104, device='cuda:0')
# discriminator, epoch1013 : tensor(0.0801, device='cuda:0')
# generator, epoch1013 : tensor(12.3950, device='cuda:0')
# discriminator, epoch1014 : tensor(0.0715, device='cuda:0')
# generator, epoch1014 : tensor(12.4973, device='cuda:0')
# discriminator, epoch1015 : tensor(0.0780, device='cuda:0')
# generator, epoch1015 : tensor(12.1077, device='cuda:0')
# discriminator, epoch1016 : tensor(0.0837, device='cuda:0')
# generator, epoch1016 : tensor(12.3836, device='cuda:0')
# discriminator, epoch1017 : tensor(0.0835, device='cuda:0')
# generator, epoch1017 : tensor(12.3896, device='cuda:0')
# discriminator, epoch1018 : tensor(0.0796, device='cuda:0')
# generator, epoch1018 : tensor(12.4256, device='cuda:0')
# discriminator, epoch1019 : tensor(0.0797, device='cuda:0')
# generator, epoch1019 : tensor(12.3839, device='cuda:0')
# discriminator, epoch1020 : tensor(0.0839, device='cuda:0')
# generator, epoch1020 : tensor(12.3214, device='cuda:0')
# discriminator, epoch1021 : tensor(0.0733, device='cuda:0')
# generator, epoch1021 : tensor(12.3732, device='cuda:0')
# discriminator, epoch1022 : tensor(0.0724, device='cuda:0')
# generator, epoch1022 : tensor(12.4206, device='cuda:0')
# discriminator, epoch1023 : tensor(0.0787, device='cuda:0')
# generator, epoch1023 : tensor(12.5993, device='cuda:0')
# discriminator, epoch1024 : tensor(0.0697, device='cuda:0')
# generator, epoch1024 : tensor(12.5863, device='cuda:0')
# discriminator, epoch1025 : tensor(0.0873, device='cuda:0')
# generator, epoch1025 : tensor(12.0622, device='cuda:0')
# discriminator, epoch1026 : tensor(0.0837, device='cuda:0')
# generator, epoch1026 : tensor(12.2672, device='cuda:0')
# discriminator, epoch1027 : tensor(0.0725, device='cuda:0')
# generator, epoch1027 : tensor(12.3976, device='cuda:0')
# discriminator, epoch1028 : tensor(0.0847, device='cuda:0')
# generator, epoch1028 : tensor(12.0526, device='cuda:0')
# discriminator, epoch1029 : tensor(0.0839, device='cuda:0')
# generator, epoch1029 : tensor(12.2051, device='cuda:0')
# discriminator, epoch1030 : tensor(0.0764, device='cuda:0')
# generator, epoch1030 : tensor(12.6527, device='cuda:0')
# discriminator, epoch1031 : tensor(0.0846, device='cuda:0')
# generator, epoch1031 : tensor(12.6107, device='cuda:0')
# discriminator, epoch1032 : tensor(0.0753, device='cuda:0')
# generator, epoch1032 : tensor(12.2172, device='cuda:0')
# discriminator, epoch1033 : tensor(0.0864, device='cuda:0')
# generator, epoch1033 : tensor(12.4436, device='cuda:0')
# discriminator, epoch1034 : tensor(0.0794, device='cuda:0')
# generator, epoch1034 : tensor(12.3357, device='cuda:0')
# discriminator, epoch1035 : tensor(0.0778, device='cuda:0')
# generator, epoch1035 : tensor(12.4241, device='cuda:0')
# discriminator, epoch1036 : tensor(0.0748, device='cuda:0')
# generator, epoch1036 : tensor(12.2448, device='cuda:0')
# discriminator, epoch1037 : tensor(0.0882, device='cuda:0')
# generator, epoch1037 : tensor(12.2526, device='cuda:0')
# discriminator, epoch1038 : tensor(0.0868, device='cuda:0')
# generator, epoch1038 : tensor(12.3161, device='cuda:0')
# discriminator, epoch1039 : tensor(0.0818, device='cuda:0')
# generator, epoch1039 : tensor(12.2567, device='cuda:0')
# discriminator, epoch1040 : tensor(0.0869, device='cuda:0')
# generator, epoch1040 : tensor(11.9668, device='cuda:0')
# discriminator, epoch1041 : tensor(0.0725, device='cuda:0')
# generator, epoch1041 : tensor(12.3558, device='cuda:0')
# discriminator, epoch1042 : tensor(0.0711, device='cuda:0')
# generator, epoch1042 : tensor(12.4398, device='cuda:0')
# discriminator, epoch1043 : tensor(0.0797, device='cuda:0')
# generator, epoch1043 : tensor(12.3567, device='cuda:0')
# discriminator, epoch1044 : tensor(0.0850, device='cuda:0')
# generator, epoch1044 : tensor(12.3395, device='cuda:0')
# discriminator, epoch1045 : tensor(0.0736, device='cuda:0')
# generator, epoch1045 : tensor(12.2780, device='cuda:0')
# discriminator, epoch1046 : tensor(0.0855, device='cuda:0')
# generator, epoch1046 : tensor(12.0047, device='cuda:0')
# discriminator, epoch1047 : tensor(0.0815, device='cuda:0')
# generator, epoch1047 : tensor(12.2279, device='cuda:0')
# discriminator, epoch1048 : tensor(0.0845, device='cuda:0')
# generator, epoch1048 : tensor(12.3421, device='cuda:0')
# discriminator, epoch1049 : tensor(0.0737, device='cuda:0')
# generator, epoch1049 : tensor(12.2672, device='cuda:0')
# discriminator, epoch1050 : tensor(0.0733, device='cuda:0')
# generator, epoch1050 : tensor(12.2939, device='cuda:0')
# discriminator, epoch1051 : tensor(0.0738, device='cuda:0')
# generator, epoch1051 : tensor(12.2568, device='cuda:0')
# discriminator, epoch1052 : tensor(0.0874, device='cuda:0')
# generator, epoch1052 : tensor(12.1290, device='cuda:0')
# discriminator, epoch1053 : tensor(0.0750, device='cuda:0')
# generator, epoch1053 : tensor(12.1817, device='cuda:0')
# discriminator, epoch1054 : tensor(0.0761, device='cuda:0')
# generator, epoch1054 : tensor(12.1144, device='cuda:0')
# discriminator, epoch1055 : tensor(0.0829, device='cuda:0')
# generator, epoch1055 : tensor(11.7523, device='cuda:0')
# discriminator, epoch1056 : tensor(0.0836, device='cuda:0')
# generator, epoch1056 : tensor(12.1049, device='cuda:0')
# discriminator, epoch1057 : tensor(0.0750, device='cuda:0')
# generator, epoch1057 : tensor(12.1612, device='cuda:0')
# discriminator, epoch1058 : tensor(0.0798, device='cuda:0')
# generator, epoch1058 : tensor(12.2968, device='cuda:0')
# discriminator, epoch1059 : tensor(0.0845, device='cuda:0')
# generator, epoch1059 : tensor(12.2615, device='cuda:0')
# discriminator, epoch1060 : tensor(0.0747, device='cuda:0')
# generator, epoch1060 : tensor(12.1713, device='cuda:0')
# discriminator, epoch1061 : tensor(0.0715, device='cuda:0')
# generator, epoch1061 : tensor(12.3675, device='cuda:0')
# discriminator, epoch1062 : tensor(0.0799, device='cuda:0')
# generator, epoch1062 : tensor(11.8841, device='cuda:0')
# discriminator, epoch1063 : tensor(0.0854, device='cuda:0')
# generator, epoch1063 : tensor(11.9821, device='cuda:0')
# discriminator, epoch1064 : tensor(0.0820, device='cuda:0')
# generator, epoch1064 : tensor(12.1396, device='cuda:0')
# discriminator, epoch1065 : tensor(0.0821, device='cuda:0')
# generator, epoch1065 : tensor(12.1166, device='cuda:0')
# discriminator, epoch1066 : tensor(0.0752, device='cuda:0')
# generator, epoch1066 : tensor(12.1271, device='cuda:0')
# discriminator, epoch1067 : tensor(0.0856, device='cuda:0')
# generator, epoch1067 : tensor(11.9667, device='cuda:0')
# discriminator, epoch1068 : tensor(0.0805, device='cuda:0')
# generator, epoch1068 : tensor(11.8397, device='cuda:0')
# discriminator, epoch1069 : tensor(0.0771, device='cuda:0')
# generator, epoch1069 : tensor(12.0177, device='cuda:0')
# discriminator, epoch1070 : tensor(0.0769, device='cuda:0')
# generator, epoch1070 : tensor(12.0205, device='cuda:0')
# discriminator, epoch1071 : tensor(0.0794, device='cuda:0')
# generator, epoch1071 : tensor(12.2908, device='cuda:0')
# discriminator, epoch1072 : tensor(0.0709, device='cuda:0')
# generator, epoch1072 : tensor(12.3630, device='cuda:0')
# discriminator, epoch1073 : tensor(0.0790, device='cuda:0')
# generator, epoch1073 : tensor(12.2622, device='cuda:0')
# discriminator, epoch1074 : tensor(0.0796, device='cuda:0')
# generator, epoch1074 : tensor(12.2724, device='cuda:0')
# discriminator, epoch1075 : tensor(0.0819, device='cuda:0')
# generator, epoch1075 : tensor(12.1281, device='cuda:0')
# discriminator, epoch1076 : tensor(0.0841, device='cuda:0')
# generator, epoch1076 : tensor(12.3073, device='cuda:0')
# discriminator, epoch1077 : tensor(0.0808, device='cuda:0')
# generator, epoch1077 : tensor(12.1412, device='cuda:0')
# discriminator, epoch1078 : tensor(0.0758, device='cuda:0')
# generator, epoch1078 : tensor(12.0748, device='cuda:0')
# discriminator, epoch1079 : tensor(0.0712, device='cuda:0')
# generator, epoch1079 : tensor(12.3383, device='cuda:0')
# discriminator, epoch1080 : tensor(0.0798, device='cuda:0')
# generator, epoch1080 : tensor(12.2340, device='cuda:0')
# discriminator, epoch1081 : tensor(0.0746, device='cuda:0')
# generator, epoch1081 : tensor(12.5057, device='cuda:0')
# discriminator, epoch1082 : tensor(0.0763, device='cuda:0')
# generator, epoch1082 : tensor(12.3841, device='cuda:0')
# discriminator, epoch1083 : tensor(0.0722, device='cuda:0')
# generator, epoch1083 : tensor(12.2774, device='cuda:0')
# discriminator, epoch1084 : tensor(0.0740, device='cuda:0')
# generator, epoch1084 : tensor(12.5619, device='cuda:0')
# discriminator, epoch1085 : tensor(0.0733, device='cuda:0')
# generator, epoch1085 : tensor(12.5550, device='cuda:0')
# discriminator, epoch1086 : tensor(0.0645, device='cuda:0')
# generator, epoch1086 : tensor(12.7466, device='cuda:0')
# discriminator, epoch1087 : tensor(0.0604, device='cuda:0')
# generator, epoch1087 : tensor(13.0486, device='cuda:0')
# discriminator, epoch1088 : tensor(0.0692, device='cuda:0')
# generator, epoch1088 : tensor(12.8132, device='cuda:0')
# discriminator, epoch1089 : tensor(0.0740, device='cuda:0')
# generator, epoch1089 : tensor(12.5649, device='cuda:0')
# discriminator, epoch1090 : tensor(0.0684, device='cuda:0')
# generator, epoch1090 : tensor(12.8545, device='cuda:0')
# discriminator, epoch1091 : tensor(0.0682, device='cuda:0')
# generator, epoch1091 : tensor(12.4913, device='cuda:0')
# discriminator, epoch1092 : tensor(0.0670, device='cuda:0')
# generator, epoch1092 : tensor(12.5723, device='cuda:0')
# discriminator, epoch1093 : tensor(0.0751, device='cuda:0')
# generator, epoch1093 : tensor(12.4631, device='cuda:0')
# discriminator, epoch1094 : tensor(0.0748, device='cuda:0')
# generator, epoch1094 : tensor(12.4073, device='cuda:0')
# discriminator, epoch1095 : tensor(0.0711, device='cuda:0')
# generator, epoch1095 : tensor(12.7400, device='cuda:0')
# discriminator, epoch1096 : tensor(0.0823, device='cuda:0')
# generator, epoch1096 : tensor(12.4180, device='cuda:0')
# discriminator, epoch1097 : tensor(0.0733, device='cuda:0')
# generator, epoch1097 : tensor(12.5032, device='cuda:0')
# discriminator, epoch1098 : tensor(0.0685, device='cuda:0')
# generator, epoch1098 : tensor(12.4528, device='cuda:0')
# discriminator, epoch1099 : tensor(0.0718, device='cuda:0')
# generator, epoch1099 : tensor(12.2573, device='cuda:0')
# discriminator, epoch1100 : tensor(0.0704, device='cuda:0')
# generator, epoch1100 : tensor(12.3402, device='cuda:0')
# discriminator, epoch1101 : tensor(0.0732, device='cuda:0')
# generator, epoch1101 : tensor(12.1699, device='cuda:0')
# discriminator, epoch1102 : tensor(0.0760, device='cuda:0')
# generator, epoch1102 : tensor(12.3740, device='cuda:0')
# discriminator, epoch1103 : tensor(0.0683, device='cuda:0')
# generator, epoch1103 : tensor(12.4732, device='cuda:0')
