# %% [markdown]
# <a href="https://colab.research.google.com/github/buganart/BUGAN/blob/master/notebook_deprecated/Blender_Offscreen_Render.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !apt remove --purge blender
# !add-apt-repository -y ppa:thomas-schiex/blender
# !apt-get update
# !apt install -y blender

# %%
# !git clone https://github.com/buganart/BUGAN

# %%
# Get one of our trees to test rendering.
# !gdown https://drive.google.com/uc?id=1QpBZICatHyZpNSR4SL_QeYXAFdbxh268

# %%
# !blender -b -E CYCLES -noaudio -P BUGAN/book_tree_survey/blender/render.py -- --input sample_tree_for_render.obj --output ./

# %%
from IPython.display import Image
# TODO check where extra underscore is coming from.
Image('sample_tree_for_render_.jpg')
